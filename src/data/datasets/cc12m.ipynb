# %%
from cc12m import CC12M

dataset = CC12M()
dataset.show_image(12)
# Out:
# Peterbilt 359 custom built show me how to find this Large Cars kits . Thanks Linton. Rc Cars And Trucks, Big Rig Trucks, Semi Trucks, Peterbilt 359, Peterbilt Trucks, Rc Model, Model Kits, Truck Scales, Plastic Model Cars
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x306 at 0x7F630855B4C0>

# %%
dataset.show_image(1920005)
# Out:
# Image of a child's hand holding a pencil with a text overlay: How to Create a Flexible Homeschool Schedule for the New School Year
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x384 at 0x7F650CF8DD00>
